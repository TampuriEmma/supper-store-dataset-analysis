# %% [markdown]
# ## Importing Labiraries
# - numpy
# - pandas
# - matplots
# - seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\UNDER PRESSURE\AppData\Local\Temp\ipykernel_11552\265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Loading, creating a copy and veiwing of data
# - Load dataset
# - creat a deep copy of dataset
# - veiwing of data

# %%
super_store = pd.read_csv("ProjectsDatasetFolder/superstore_data.csv",encoding = "latin-1")
super_store_df = super_store.copy()

# %%
super_store_df
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %% [markdown]
# ## Data Overview
#
# - index
# - columns
# - size
# - shape

# %%
super_store_df.index
# Out:
# RangeIndex(start=0, stop=51290, step=1)

# %%
super_store_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
super_store_df.size
# Out:
# 1230960

# %%
print ("The number of Rows are :",super_store_df.shape[0],"The number of columns are :",super_store_df.shape[1])
# Out:
# The number of Rows are : 51290 The number of columns are : 24

# %%
## Checking for datatype of out data
super_store_df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %% [markdown]
# ## Unique Instances of our data

# %%
print (np.unique(super_store_df['Row ID']))
# Out:
# [    1     2     3 ... 51288 51289 51290]

# %%
print (np.unique(super_store_df['Order ID']))
# Out:
# ['AE-2011-9160' 'AE-2013-1130' 'AE-2013-1530' ... 'ZI-2014-9540'
#  'ZI-2014-9550' 'ZI-2014-9650']

# %%
print (np.unique(super_store_df['Order Date']))
# Out:
# ['1/1/2011' '1/1/2013' '1/1/2014' ... '9/9/2012' '9/9/2013' '9/9/2014']

# %%
print (pd.unique(super_store_df['Ship Date']))
# Out:
# ['6/1/2011' '8/1/2011' '5/1/2011' ... '5/1/2015' '6/1/2015' '7/1/2015']

# %%
print (np.unique(super_store_df['Ship Mode']))
# Out:
# ['First Class' 'Same Day' 'Second Class' 'Standard Class']

# %%
print (pd.unique(super_store_df['Customer ID']))
# Out:
# ['TB-11280' 'JH-15985' 'AT-735' ... 'KM-6225' 'NM-8520' 'BD-1500']

# %%
print (pd.unique(super_store_df['Customer Name']))
# Out:
# ['Toby Braunhardt' 'Joseph Holt' 'Annie Thurman' 'Eugene Moren'
#  "Patrick O'Donnell" 'Liz Carlisle' 'David Kendrick' 'Stephanie Phelps'
#  'Dave Hallsten' "Patrick O'Brill" 'Gene Hale' 'Ralph Ritter'
#  'Ionia McGrath' 'Tom Prescott' 'Todd Sumrall' 'Ruben Dartt'
#  'Tom Boeckenhauer' 'Vicky Freymann' 'Katherine Hughes' 'Dave Brooks'
#  'Giulietta Weimer' 'Shahid Collister' 'Bryan Spruell' 'Chris McAfee'
#  'Randy Ferguson' 'Logan Haushalter' 'Lori Olson' 'Ed Ludwig'
#  'Brian DeCherney' 'Jeremy Farry' 'Edward Hooks' 'Hallie Redmond'
#  'Aaron Smayling' 'Benjamin Patterson' 'Rachel Payne' 'Jennifer Braxton'
#  'Pete Armstrong' 'Victoria Pisteka' 'Lynn Smith' 'Kunst Miller'
#  'Katharine Harms' 'Adam Bellavance' 'Matt Hagelstein' 'Dianna Wilson'
#  'Liz Thompson' 'Mike Caudle' 'Yana Sorensen' 'Muhammed MacIntyre'
#  'Nick Zandusky' 'Monica Federle' 'William Brown' 'Claudia Bergmann'
#  'Corey Roper' 'Deborah Brumfield' 'Quincy Jones' 'Eric Barreto'
# ...

# %%
print (pd.unique(super_store_df['Segment']))
# Out:
# ['Consumer' 'Home Office' 'Corporate']

# %%
print (pd.unique(super_store_df['City']))
# Out:
# ['Constantine' 'Wagga Wagga' 'Budapest' ... 'Missoula' 'Lannion'
#  'Deer Park']

# %%
print (pd.unique(super_store_df['State']))
# Out:
# ['Constantine' 'New South Wales' 'Budapest' ... 'Medea' 'Jizzakh'
#  'Inhambane']

# %%
print (pd.unique(super_store_df['Country']))
# Out:
# ['Algeria' 'Australia' 'Hungary' 'Sweden' 'Bangladesh' 'United States'
#  'Angola' 'China' 'Panama' 'Iran' 'France' 'Italy' 'Germany' 'Canada'
#  'United Kingdom' 'Ukraine' 'Japan' 'Indonesia' 'Nigeria' 'South Korea'
#  'Peru' 'Philippines' 'Colombia' 'Ireland' 'Nicaragua' 'Mexico' 'Brazil'
#  'Turkey' 'Spain' 'Poland' 'India' 'Somalia' 'El Salvador' 'Sudan'
#  'Slovakia' 'Egypt' 'Saudi Arabia' 'Democratic Republic of the Congo'
#  'Norway' 'New Zealand' 'Kenya' 'Cuba' 'Venezuela' 'Singapore' 'Honduras'
#  'Tanzania' 'Dominican Republic' 'Morocco' 'Albania' 'Belgium'
#  'Afghanistan' 'Bolivia' 'Vietnam' 'Guatemala' 'Guinea-Bissau' 'Thailand'
#  'Iraq' 'Myanmar (Burma)' 'Ecuador' 'Netherlands' 'Ghana' "Cote d'Ivoire"
#  'Austria' 'Argentina' 'Madagascar' 'Russia' 'South Africa'
#  'Bosnia and Herzegovina' 'Malaysia' 'Romania' 'Israel' 'Burundi'
#  'Cameroon' 'Paraguay' 'Senegal' 'Georgia' 'Kazakhstan'
#  'United Arab Emirates' 'Pakistan' 'Liberia' 'Czech Republic' 'Jamaica'
# ...

# %%
print (pd.unique(super_store_df['Postal Code']))
# Out:
# [   nan 92691. 60126. 98115. 77036. 79907. 10035. 94591.  2151. 55044.
#  72209.  8701. 48234. 32725. 98105. 28205. 94122. 19120. 10009. 92025.
#  89502. 80219. 97206. 11561.  7050. 40475. 45040. 90049. 60610. 53711.
#  43229. 77070.  1852. 28540. 54302. 30605. 23464. 77095. 33801. 30076.
#  84057.  7060. 65807. 72701. 60089. 60653. 13601. 85281. 33311. 44256.
#  10024. 75061. 20735. 78415. 30328. 60623. 33710. 92037. 28403. 90008.
#  10701. 54915. 62521. 48640. 85301. 60201. 90036. 27707. 75217. 17602.
#  68104. 37211.  6824. 73120. 63116. 29203. 33063. 70506. 48205. 94109.
#   6457. 49201. 80013. 23223. 84062.  4401. 90045. 27511. 10011. 90805.
#  60540. 92024. 22304. 48127. 78207. 22204. 61032. 39212. 32137. 90004.
#  37918.  6450. 77590. 43402. 91767. 19143. 23666. 85234. 19134. 90032.
#  32216. 14609. 92020. 46203. 31907. 97477. 38109. 42420. 23320. 60441.
#  98103. 98198. 30062. 36608.  1841. 60505. 61604. 74133. 60543. 95051.
# ...

# %%
print (pd.unique(super_store_df['Market']))
# Out:
# ['Africa' 'APAC' 'EMEA' 'EU' 'US' 'LATAM' 'Canada']

# %%
print (pd.unique(super_store_df['Region']))
# Out:
# ['Africa' 'Oceania' 'EMEA' 'North' 'Central Asia' 'West' 'North Asia'
#  'Central' 'South' 'Canada' 'Southeast Asia' 'East' 'Caribbean']

# %%
print (pd.unique(super_store_df['Product ID']))
# Out:
# ['OFF-TEN-10000025' 'OFF-SU-10000618' 'OFF-TEN-10001585' ...
#  'OFF-AP-10000437' 'OFF-FA-10002639' 'FUR-BO-10001746']

# %%
print (pd.unique(super_store_df['Profit']))
# Out:
# [106.14    36.036   29.64   ... -37.266    6.475   -0.6048]

# %%
print (pd.unique(super_store_df['Shipping Cost']))
# Out:
# [ 35.46   9.72   8.17 ... 138.18  86.86  52.11]

# %%
print (pd.unique(super_store_df['Order Priority']))
# Out:
# ['Medium' 'High' 'Critical' 'Low']

# %% [markdown]
# ### Replace nan in postal code using count function

# %%
## check for the count of each postal code
super_store_df['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035.0    263
# 10024.0    230
# 10009.0    229
# 94122.0    203
# 10011.0    193
#           ...
# 48858.0      1
# 60462.0      1
# 83501.0      1
# 94061.0      1
# 77536.0      1
# Name: count, Length: 631, dtype: int64

# %%
## select the index for the highest count
super_store_df['Postal Code'].value_counts().index[0]
# Out:
# 10035.0

# %%
## replace the nans with the highest counts of postal code
super_store_df['Postal Code'] = super_store_df['Postal Code'].fillna(super_store_df['Postal Code'].value_counts().index[0])

# %% [markdown]
# ### Check for NaN in our data

# %%
super_store_df['Postal Code'].isnull().sum()
# Out:
# 0

# %%
super_store_df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Postal Code       0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %% [markdown]
# ### changing datatype
# - Ship Date
# - Order Date
# - Ship Mode
# - Segment
# - Market
# - Region
# - Category
# - Sub-Category
# - Order Priority

# %%
super_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     51290 non-null  float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
super_store_df['Order Date'] = super_store_df['Order Date'].astype('datetime64[ns]')

# %%
super_store_df['Ship Date'] = super_store_df['Ship Date'].astype('datetime64[ns]')

# %%
super_store_df['Ship Mode'] = super_store_df['Ship Mode'].astype('category')

# %%
super_store_df['Segment'] = super_store_df['Segment'].astype('category')

# %%
super_store_df['Market'] = super_store_df['Market'].astype('category')

# %%
super_store_df['Region'] = super_store_df['Region'].astype('category')

# %%
super_store_df['Category'] = super_store_df['Category'].astype('category')

# %%
super_store_df['Sub-Category'] = super_store_df['Sub-Category'].astype('category')

# %%
super_store_df['Order Priority'] = super_store_df['Order Priority'].astype('category')

# %% [markdown]
# ### Check if changing of datatype has taken effect

# %%
super_store_df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode               category
# Customer ID               object
# Customer Name             object
# Segment                 category
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                  category
# Region                  category
# Product ID                object
# Category                category
# Sub-Category            category
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority          category
# dtype: object

# %% [markdown]
# ## Data Description
# - Group out data and veiw them
# - check correlation

# %%
super_store_df.describe().round()
# Out:
#         Row ID                     Order Date                      Ship Date  \
# count  51290.0                          51290                          51290
# mean   25646.0  2013-04-30 17:16:21.384285440  2013-05-05 19:10:10.504971776
# min        1.0            2011-01-01 00:00:00            2011-01-02 00:00:00
# 25%    12823.0            2012-06-06 00:00:00            2012-06-13 00:00:00
# 50%    25646.0            2013-06-26 00:00:00            2013-06-30 00:00:00
# 75%    38468.0            2014-04-30 00:00:00            2014-05-09 00:00:00
# max    51290.0            2014-12-31 00:00:00            2015-07-01 00:00:00
# std    14806.0                            NaN                            NaN
#
#        Postal Code    Sales  Quantity  Discount   Profit  Shipping Cost
# count      51290.0  51290.0   51290.0   51290.0  51290.0        51290.0
# mean       18834.0    246.0       3.0       0.0     29.0           26.0
# ...

# %%
num = ['Row ID','Order Date','Ship Date','Postal Code','Sales','Quantity','Discount','Profit','Shipping Cost']
numdf = super_store_df[num]
cat = ['Order ID','Ship Mode','Segment','Market','Region','Category','Sub-Category','Order Priority']
catdf = super_store_df[cat]

# %%
numdf
# Out:
#        Row ID Order Date  Ship Date  Postal Code    Sales  Quantity  Discount  \
# 0       42433 2011-01-01 2011-06-01      10035.0  408.300         2       0.0
# 1       22253 2011-01-01 2011-08-01      10035.0  120.366         3       0.1
# 2       48883 2011-01-01 2011-05-01      10035.0   66.120         4       0.0
# 3       11731 2011-01-01 2011-05-01      10035.0   44.865         3       0.5
# 4       22255 2011-01-01 2011-08-01      10035.0  113.670         5       0.1
# ...       ...        ...        ...          ...      ...       ...       ...
# 51285   32593 2014-12-31 2015-04-01      94533.0   13.904         2       0.2
# 51286   47594 2014-12-31 2015-05-01      10035.0    3.990         1       0.0
# 51287    8857 2014-12-31 2015-02-01      10035.0   26.400         3       0.0
# 51288    6852 2014-12-31 2015-06-01      10035.0    7.120         1       0.0
# 51289   36388 2014-12-31 2015-04-01      80538.0    3.024         3       0.2
#
#          Profit  Shipping Cost
# ...

# %%
catdf
# Out:
#               Order ID       Ship Mode      Segment  Market   Region  \
# 0         AG-2011-2040  Standard Class     Consumer  Africa   Africa
# 1        IN-2011-47883  Standard Class     Consumer    APAC  Oceania
# 2         HU-2011-1220    Second Class     Consumer    EMEA     EMEA
# 3      IT-2011-3647632    Second Class  Home Office      EU    North
# 4        IN-2011-47883  Standard Class     Consumer    APAC  Oceania
# ...                ...             ...          ...     ...      ...
# 51285   CA-2014-115427  Standard Class    Corporate      US     West
# 51286     MO-2014-2560  Standard Class     Consumer  Africa   Africa
# 51287   MX-2014-110527    Second Class     Consumer   LATAM  Central
# 51288   MX-2014-114783  Standard Class     Consumer   LATAM    North
# 51289   CA-2014-156720  Standard Class     Consumer      US     West
#
#               Category Sub-Category Order Priority
# 0      Office Supplies      Storage         Medium
# ...

# %%
numdf.corr()
# Out:
#                  Row ID  Order Date  Ship Date  Postal Code     Sales  \
# Row ID         1.000000   -0.008689  -0.005318     0.277950 -0.043889
# Order Date    -0.008689    1.000000   0.972175    -0.012431 -0.002817
# Ship Date     -0.005318    0.972175   1.000000    -0.009929 -0.003103
# Postal Code    0.277950   -0.012431  -0.009929     1.000000 -0.021512
# Sales         -0.043889   -0.002817  -0.003103    -0.021512  1.000000
# Quantity      -0.173483   -0.002387  -0.003240     0.056406  0.313577
# Discount       0.087594   -0.005426  -0.005141     0.039730 -0.086722
# Profit        -0.019037    0.001302   0.002982    -0.010925  0.484918
# Shipping Cost -0.039078   -0.002236  -0.004138    -0.024304  0.768073
#
#                Quantity  Discount    Profit  Shipping Cost
# Row ID        -0.173483  0.087594 -0.019037      -0.039078
# Order Date    -0.002387 -0.005426  0.001302      -0.002236
# Ship Date     -0.003240 -0.005141  0.002982      -0.004138
# ...

# %% [markdown]
# ### Create additional column for time taken from order date to ship date
# - Number of days it takes for an order to be shipped

# %%
super_store_df['Time Taken to Ship'] = super_store_df['Ship Date'] - super_store_df['Order Date']
super_store_df['Time Taken to Ship']
# Out:
# 0       151 days
# 1       212 days
# 2       120 days
# 3       120 days
# 4       212 days
#           ...
# 51285    91 days
# 51286   121 days
# 51287    32 days
# 51288   152 days
# 51289    91 days
# Name: Time Taken to Ship, Length: 51290, dtype: timedelta64[ns]

# %%
super_store_df['Time Taken to Ship'].value_counts()
# Out:
# Time Taken to Ship
# 4 days       7166
# 5 days       5459
# 2 days       4007
# 6 days       2836
# 3 days       2635
#              ...
# -29 days        5
# -147 days       3
# -21 days        3
# -50 days        2
# -294 days       2
# Name: count, Length: 152, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
plt.scatter(super_store_df['Shipping Cost'], super_store_df['Sales'],c="red")

plt.title('Relation between Shipping Cost and Sales')

plt.ylabel('Sales')

plt.xlabel('Shipping Cost')

plt.savefig('shipping_cost_sales_rel.png')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
my_plot = sns.countplot(x=super_store_df['Market'],color="green")
my_plot.set_xticklabels(my_plot.get_xticklabels(),rotation=90)
plt.title('Destribtion of Market')
plt.grid(axis='y')
plt.xlabel('Markets')

plt.savefig('markets_counts.png')

plt.show
# Out:
# C:\Users\UNDER PRESSURE\AppData\Local\Temp\ipykernel_11552\2074843474.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   my_plot.set_xticklabels(my_plot.get_xticklabels(),rotation=90)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x=super_store_df['Ship Mode'],color="green")
plt.title('Destribtion of Shipping Mode')
plt.grid(axis='y')
plt.xlabel('Shipping Mode')

plt.savefig('Shipping_Mode_counts.png')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(super_store_df, y='Shipping Cost', x='Ship Mode', errorbar=None)

plt.grid(axis='y')
plt.title("Shipping Mode that Cost More")
plt.xlabel('Shipping Mode')
plt.ylabel('Shipping Cost (Dollars)')


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(super_store_df, x='Ship Mode', hue='Order Priority')


plt.title("Relationship between the Shipping Mode of Prodects and Order Priority")
plt.xlabel('Shipping Mode')
plt.grid(True,axis='y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,8))
sns.barplot(super_store_df, y='Sales', x='Sub-Category', errorbar=None)

plt.title("Relationship between the Sub-Category of Prodects and Profit")
plt.xlabel('Product Sub-Category')
plt.ylabel('Profit (Dollars)')
plt.grid(True,axis='y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,8))
sns.barplot(super_store_df, y='Profit', x='Sub-Category', errorbar=None)

plt.title("Relationship between the Sub-Category of Prodects and Profit")
plt.xlabel('Product Category')
plt.ylabel('Profit (Dollars)')
plt.grid(True,axis='y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,8))
sns.barplot(super_store_df, y='Discount', x='Sub-Category', errorbar=None,color = 'green')

plt.title("Relationship between the Sub-Category of Prodects and Discount")
plt.xlabel('Product Sub-Category')
plt.ylabel('Discounts')
plt.grid(True,axis='y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(18,8))
sns.barplot(super_store_df, x='Sub-Category', y='Quantity', errorbar=None, color='brown')


plt.title("Relationship between Sub-Category of Prodects and Quantity")

plt.grid(True,axis='y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,10))
sub_category_count = super_store_df['Sub-Category'].value_counts()
plt.pie(sub_category_count, labels = sub_category_count.index ,autopct='%1.1f%%')
plt.title("Destribution of Sub-Category of Products")
plt.show()

# %%
sns.barplot(super_store_df, y='Sales', x='Quantity', errorbar=None, color='brown')


plt.title("Relationship between Quantity and Sales")

plt.grid(axis='y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
